# %% [markdown]
# <a href="https://colab.research.google.com/github/Dilan-Sazan/SoftiTO/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('/content/drive/MyDrive/veri_setleri/ispark_parking.csv')
print(df.shape)
df.head()
# Out:
# (708, 9)
#                PARK_NAME               LOCATION_NAME PARK_TYPE_ID  \
# 0  Vali Konağı Caddesi 1    Şişli Vali Konağı Caddes     YOL ÜSTÜ
# 1        Şakayık Sokak 1          Şişli Şakayık Soka     YOL ÜSTÜ
# 2  Hüsrev Gerede Sokak 1  Şişli Hüsrev Gerede Caddes     YOL ÜSTÜ
# 3    Sezai Selek Sokak 1         Seza-i Selek Caddes     YOL ÜSTÜ
# 4        Maçka Caddesi 1          Şişli Maçka Caddes     YOL ÜSTÜ
#
#   PARK_TYPE_DESC  CAPACITY_OF_PARK WORKING_TIME COUNTY_NAME  LONGITUDE  \
# 0       YOL ÜSTÜ                30  08:00-19:00       ŞİŞLİ  28.987975
# 1       YOL ÜSTÜ                50  08:00-19:00       ŞİŞLİ  28.995566
# 2       YOL ÜSTÜ                50  08:00-19:00       ŞİŞLİ  28.994976
# 3       YOL ÜSTÜ                50  08:00-19:00       ŞİŞLİ  28.995974
# 4       YOL ÜSTÜ                40  08:00-00:00       ŞİŞLİ  28.992955
#
#     LATITUDE
# 0  41.048823
# 1  41.049523
# 2  41.048390
# 3  41.053386
# 4  41.046630

# %%
bad_coords = df[(df['LATITUDE'] < 30) | (df['LONGITUDE'] < 20)]
bad_coords[['PARK_NAME', 'COUNTY_NAME', 'LONGITUDE', 'LATITUDE', 'CAPACITY_OF_PARK']]
# Out:
#                                              PARK_NAME COUNTY_NAME  LONGITUDE  \
# 326                   Bağcılar Kent Meydanı Zemin Altı    BAĞCILAR      -99.0
# 334  Avcılar Mustafa Kemalpaşa Metrobüs Durağı  yan...     AVCILAR      -99.0
# 496               Kayaşehir Meydan Zemin Altı Otoparkı  BAŞAKŞEHİR      -99.0
# 682                         Levent Büyükdere Caddesi 4    BEŞİKTAŞ      -99.0
#
#      LATITUDE  CAPACITY_OF_PARK
# 326     -99.0              1162
# 334     -99.0                44
# 496     -99.0              1054
# 682     -99.0                30
